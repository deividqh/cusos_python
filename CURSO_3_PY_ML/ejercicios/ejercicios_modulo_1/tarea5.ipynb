# %%
def derivada(x):
    """
        Calcula la pendiente de una curva f(x) = x^2 en un punto dado x 
    """
    return 2 * x


x_inicial = 10          # empiezas el calculo en la cima(lejos del minimo donde quiero llegar).
tasa_aprendizaje = 0.1  # el tamaño del paso que se da en cada iteración. (Learning Rate).
num_iteraciones = 20    # cuantos pasos doy para bajar la curva hacia el valle(minimo).

x = x_inicial
print(f'inicio: arrancan en posicion x=x_inicial={x_inicial}')

for i in range(num_iteraciones):
    pendiente = derivada(x)                         # calculo la pendiente en el punto actual
    x = x - tasa_aprendizaje * pendiente            # actualizo x restando el paso dado por la pendiente
    coste = x**2                                   # calculo el coste (valor de la función) en el nuevo punto
    print(f'iteracion {i+1}: x={x:2.4f}, pendiente={pendiente:.4f}, coste={coste:.4f}')
# Out:
# inicio: arrancan en posicion x=x_inicial=10
# iteracion 1: x=8.0000, pendiente=20.0000, coste=64.0000
# iteracion 2: x=6.4000, pendiente=16.0000, coste=40.9600
# iteracion 3: x=5.1200, pendiente=12.8000, coste=26.2144
# iteracion 4: x=4.0960, pendiente=10.2400, coste=16.7772
# iteracion 5: x=3.2768, pendiente=8.1920, coste=10.7374
# iteracion 6: x=2.6214, pendiente=6.5536, coste=6.8719
# iteracion 7: x=2.0972, pendiente=5.2429, coste=4.3980
# iteracion 8: x=1.6777, pendiente=4.1943, coste=2.8147
# iteracion 9: x=1.3422, pendiente=3.3554, coste=1.8014
# iteracion 10: x=1.0737, pendiente=2.6844, coste=1.1529
# iteracion 11: x=0.8590, pendiente=2.1475, coste=0.7379
# iteracion 12: x=0.6872, pendiente=1.7180, coste=0.4722
# iteracion 13: x=0.5498, pendiente=1.3744, coste=0.3022
# iteracion 14: x=0.4398, pendiente=1.0995, coste=0.1934
# iteracion 15: x=0.3518, pendiente=0.8796, coste=0.1238
# iteracion 16: x=0.2815, pendiente=0.7037, coste=0.0792
# iteracion 17: x=0.2252, pendiente=0.5629, coste=0.0507
# iteracion 18: x=0.1801, pendiente=0.4504, coste=0.0325
# iteracion 19: x=0.1441, pendiente=0.3603, coste=0.0208
# iteracion 20: x=0.1153, pendiente=0.2882, coste=0.0133
