# %% [markdown]
# # Tarea 3

# %%
# Contrel de versiones

import sys
import numpy as np
import pandas as pd

print(f"Control de versiones: {sys.version}")
print(f"NumPy: {np.__version__}")
print(f"Pandas: {pd.__version__}")
print("Chaooo 👋👋👋")
# Out:
# Control de versiones: 3.10.20 | packaged by Anaconda, Inc. | (main, Mar 11 2026, 17:42:35) [MSC v.1942 64 bit (AMD64)]
# NumPy: 2.2.6
# Pandas: 2.3.3
# Chaooo 👋👋👋
